# %%
#!pip install bing-image-downloader
#!pip install google_images_download

# %%
# !mkdir images
# Out:
# mkdir: images: File exists

# %%
from bing_image_downloader import downloader
downloader.download("referee showing yellow card in soccer", limit =150, output_dir='images')
# Out:
# [%] Downloading Images to /Users/rishintiwari/Desktop/Spring 2024/Data Science Programming/Final Project/images/referee showing yellow card in soccer
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://cosmosmagazine.com/wp-content/uploads/2020/02/181001-referee-full.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://thumbs.dreamstime.com/z/soccer-referee-showing-yellow-card-29645373.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://eplindex.com/wp-content/uploads/Referee-Red-Card.png
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://imgresizer.eurosport.com/unsafe/1200x0/filters:format(jpeg)/origin-imgresizer.eurosport.com/2007/01/23/332677-24087120-2560-1440.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://img.freepik.com/premium-vector/soccer-referee-showing-yellow-card_42875-158.jpg
# [%] File Downloaded !
#
# ...
